# %%
import torchHED
import PIL
   
# process a PIL.Image loaded in memory and return a new PIL.Image
img = PIL.Image.open("localfiles/2colortexture.jpg")
img = img.resize((480,320))
img_hed = torchHED.process_img(img)
# Out:
# c:\Users\u0146408\Documents\DoctoraatLocal\generic-segmentation-tools\env\lib\site-packages\torchHED\hed.py:108: UserWarning: Warning, image size (W,H)=(480,320), there is no guarantee for correctness for (W,H) different from (480,320)
#   warnings.warn(

# %%
display(img_hed)
# Out:
# <PIL.Image.Image image mode=L size=480x320>
